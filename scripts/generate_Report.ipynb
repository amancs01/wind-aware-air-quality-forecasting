# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent

print(PROJECT_ROOT)
# Out:
# c:\Users\ACER\OneDrive\Desktop\wind-aware-air-quality-forecasting

# %%
weather = pd.read_csv(
    PROJECT_ROOT /
    "data/raw/weather/Bagdol/Bagdol_2021.csv"
)

weather.head()
# Out:
#           timestamp  temperature  humidity  dew_point  pressure  wind_speed  \
# 0  2021-01-01T00:00          7.5        60        0.3     871.0         4.4
# 1  2021-01-01T01:00          6.7        58       -0.9     870.1         3.7
# 2  2021-01-01T02:00          5.9        55       -2.4     869.5         3.3
# 3  2021-01-01T03:00          5.5        49       -4.3     869.4         2.6
# 4  2021-01-01T04:00          5.5        43       -6.0     869.3         3.3
#
#    wind_direction  precipitation station   latitude  longitude
# 0             171            0.0  Bagdol  27.671706  85.301619
# 1             169            0.0  Bagdol  27.671706  85.301619
# 2             167            0.0  Bagdol  27.671706  85.301619
# 3             164            0.0  Bagdol  27.671706  85.301619
# 4             167            0.0  Bagdol  27.671706  85.301619

# %%
air = pd.read_csv(
    PROJECT_ROOT /
    "data/raw/air_quality/Bagdol/Bagdol_2026.csv"
)

air.head()
# Out:
#                    timestamp      pm2_5
# 0  2026-02-06T13:45:00+05:45  52.603111
# 1  2026-02-06T14:45:00+05:45  65.027667
# 2  2026-02-06T15:45:00+05:45  52.348805
# 3  2026-02-06T16:45:00+05:45  57.167818
# 4  2026-02-06T17:45:00+05:45  70.019000

# %%
merged = pd.read_csv("../data/processed/merged/Embassy Kathmandu.csv")

merged[merged["pm2_5"].notna()].head(5)
# Out:
#              timestamp  temperature  humidity  dew_point  pressure  \
# 5  2021-01-01 05:00:00          2.6        84        0.1     863.2
# 6  2021-01-01 06:00:00          2.8        81       -0.1     863.7
# 7  2021-01-01 07:00:00          4.0        76        0.1     864.9
# 8  2021-01-01 08:00:00         10.0        55        1.4     868.8
# 9  2021-01-01 09:00:00         14.6        27       -4.3     871.4
#
#    wind_speed  wind_direction  precipitation            station   latitude  \
# 5         5.4             132            0.0  Embassy Kathmandu  27.738703
# 6         6.4             133            0.0  Embassy Kathmandu  27.738703
# 7         7.4             129            0.0  Embassy Kathmandu  27.738703
# 8         6.9             129            0.0  Embassy Kathmandu  27.738703
# 9         1.6             153            0.0  Embassy Kathmandu  27.738703
#
#    longitude  pm2_5
# 5  85.336206   96.0
# 6  85.336206   91.0
# 7  85.336206  114.0
# 8  85.336206  141.0
# ...

# %%
trimmed = pd.read_csv("../data/processed/trimmed/Embassy Kathmandu.csv")
trimmed.head(10)
# Out:
#              timestamp  temperature  humidity  dew_point  pressure  \
# 0  2021-01-01 05:00:00          2.6        84        0.1     863.2
# 1  2021-01-01 06:00:00          2.8        81       -0.1     863.7
# 2  2021-01-01 07:00:00          4.0        76        0.1     864.9
# 3  2021-01-01 08:00:00         10.0        55        1.4     868.8
# 4  2021-01-01 09:00:00         14.6        27       -4.3     871.4
# 5  2021-01-01 10:00:00         16.2        23       -4.8     871.6
# 6  2021-01-01 11:00:00         17.3        23       -3.8     871.4
# 7  2021-01-01 12:00:00         18.2        23       -3.3     870.7
# 8  2021-01-01 13:00:00         18.1        25       -2.5     869.8
# 9  2021-01-01 14:00:00         17.3        28       -1.2     869.0
#
#    wind_speed  wind_direction  precipitation            station   latitude  \
# 0         5.4             132            0.0  Embassy Kathmandu  27.738703
# 1         6.4             133            0.0  Embassy Kathmandu  27.738703
# ...

# %%
trimmed = pd.read_csv(
    PROJECT_ROOT /
    "data/processed/trimmed/Bagdol.csv"
)

trimmed.head()
# Out:
#              timestamp  temperature  humidity  dew_point  pressure  \
# 0  2026-02-06 13:00:00         18.8        46        7.0     875.3
# 1  2026-02-06 14:00:00         18.2        50        7.7     874.6
# 2  2026-02-06 15:00:00         17.3        54        7.9     873.7
# 3  2026-02-06 16:00:00         16.0        59        8.1     873.1
# 4  2026-02-06 17:00:00         13.3        72        8.4     872.2
#
#    wind_speed  wind_direction  precipitation station   latitude  longitude  \
# 0         8.3             326            0.0  Bagdol  27.671706  85.301619
# 1         8.6             327            0.0  Bagdol  27.671706  85.301619
# 2         9.1             335            0.0  Bagdol  27.671706  85.301619
# 3         7.1             350            0.0  Bagdol  27.671706  85.301619
# 4         3.0              17            0.0  Bagdol  27.671706  85.301619
#
#        pm2_5
# 0  52.603111
# 1  65.027667
# 2  52.348805
# 3  57.167818
# 4  70.019000

# %%
import pandas as pd
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

featured = pd.read_csv(
    PROJECT_ROOT / "data/processed/featured/Embassy Kathmandu.csv"
)

# Show first rows where all engineered features are available
featured.dropna().head()
# Out:
#               timestamp  temperature  humidity  dew_point  pressure  \
# 72  2021-01-04 05:00:00         13.8        49        3.4     869.0
# 73  2021-01-04 06:00:00         11.3        65        4.8     868.0
# 74  2021-01-04 07:00:00         11.9        61        4.6     868.9
# 75  2021-01-04 08:00:00         13.2        61        5.8     869.8
# 76  2021-01-04 09:00:00         15.7        55        6.8     871.2
#
#     wind_speed  wind_direction  precipitation            station   latitude  \
# 72         3.0              76            0.0  Embassy Kathmandu  27.738703
# 73         3.7             151            0.0  Embassy Kathmandu  27.738703
# 74         4.8             138            0.1  Embassy Kathmandu  27.738703
# 75         6.9             141            0.0  Embassy Kathmandu  27.738703
# 76         6.4             133            0.0  Embassy Kathmandu  27.738703
#
#     longitude  pm2_5  hour  day  month  weekday  lag_1  lag_3  lag_6  lag_12  \
# ...

# %%
train = pd.read_csv(
    PROJECT_ROOT /
    "data/processed/split/train/Bagdol.csv"
)

train.head()
# Out:
#              timestamp  temperature  humidity  dew_point  pressure  \
# 0  2026-02-06 13:00:00         18.8        46        7.0     875.3
# 1  2026-02-06 14:00:00         18.2        50        7.7     874.6
# 2  2026-02-06 15:00:00         17.3        54        7.9     873.7
# 3  2026-02-06 16:00:00         16.0        59        8.1     873.1
# 4  2026-02-06 17:00:00         13.3        72        8.4     872.2
#
#    wind_speed  wind_direction  precipitation station   latitude  ...  \
# 0         8.3             326            0.0  Bagdol  27.671706  ...
# 1         8.6             327            0.0  Bagdol  27.671706  ...
# 2         9.1             335            0.0  Bagdol  27.671706  ...
# 3         7.1             350            0.0  Bagdol  27.671706  ...
# 4         3.0              17            0.0  Bagdol  27.671706  ...
#
#    rolling_std_3  rolling_std_6  rolling_std_24    wind_u    wind_v  hour_sin  \
# ...

# %%
validation = pd.read_csv(
    PROJECT_ROOT /
    "data/processed/split/validation/Bagdol.csv"
)

validation.head()
# Out:
#              timestamp  temperature  humidity  dew_point  pressure  \
# 0  2026-04-25 15:00:00         23.2        61       15.3     873.0
# 1  2026-04-25 16:00:00         23.2        62       15.4     872.8
# 2  2026-04-25 17:00:00         18.9        84       16.1     872.4
# 3  2026-04-25 18:00:00         18.2        94       17.2     872.3
# 4  2026-04-25 19:00:00         17.8        97       17.3     871.8
#
#    wind_speed  wind_direction  precipitation station   latitude  ...  \
# 0         3.1             306            0.0  Bagdol  27.671706  ...
# 1         3.9              13            0.0  Bagdol  27.671706  ...
# 2         7.0              44            0.0  Bagdol  27.671706  ...
# 3         5.4             143            1.5  Bagdol  27.671706  ...
# 4         6.7             156            1.1  Bagdol  27.671706  ...
#
#    rolling_std_3  rolling_std_6  rolling_std_24    wind_u    wind_v  hour_sin  \
# ...
